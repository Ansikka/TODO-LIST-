# %%
import matplotlib.pyplot as plt
import numpy as np
xcode=([10,5,20,45,10,10])
mylabels=["python","sql","excel","power bi","python libraries","maths and stats"]
myexplode=[0.2,0,0,0,0,0]
plt.pie(xcode,labels=mylabels,explode=myexplode,shadow=True)
plt.legend(title="Data Analyst:")
plt.show()
